# %% [markdown]
# # Statistics is the foundation of the science of data. It involves collecting, classifying, summarizing, analyzing, and interpreting numerical information.
# Statistics is used in several different disciplines (both scientific and non-scientific) to make decisions and draw conclusions based on data.
#
# Population(μ):- refers to the entire group or set of individuals, items, or subjects that possess certain characteristics.
# sample(n):- it is a subset of the Population. it is mostly used in inferential statistics
#
# In statistics (1) Descriptive statistics - describing data mean, median, mode, variance, co-variance, etc with visualizations by using the tool seaborn.
# (2) Inferential statistics - Utilizes sample data to make estimations, decisions, predictions, or other generalizations about a large set of data.
# - Inferential statistics to validate Tests based on the z-test, t-test and we can say the most commonly used inferential technique is Hypothesis testing
#
# Data types - Nominal, Ordinal, Interval scale, Ratio scale and categorizing Continuous and discrete
#
# Measure of central Tendency:- are statistical indicators that provide insight into the central or average value within a dataset. These measures summarize the center or typical value of a distribution. The commonly used measures of central tendency include:
# "Mean", "mode", and "Median" these helpful in drawing the outliers on the base of uniform distribution, and with the Boxplot by replacing it in missing values. Also Measure of Variability with "variance" and "standard Deviation"
# can also help in Identifying outliers on
# "Skewed distribution"(+ or - distribution),
#  "Uniform Distribution", "Kurtosis"(wider peak and thinner tails of distribution),
# Lepto Kurtic >3(Tall peak, median peak, low peak),
# Meso Kurtic = 3(Normal Distribution), and
# PlatyKurtic <3(low peak) on Deviation distance graph
#
# Graphs and chart:-
# Bar chart, Scatterplot, boxplot, histogram, line plot mostly used
#
# These all come under Descriptive Exploratory Data analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import kurtosis
#ignore harmless warnings
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\SHIVA KUMAR\Desktop\Assigmnt\SLR\delivery_time.csv")
data.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
data.columns #As per data Both columns are in Ratio Scale
# Out:
# Index(['Delivery Time', 'Sorting Time'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 468.0 bytes

# %%
df = pd.DataFrame(data)

# %%
df = pd.DataFrame(data)
plt.figure(figsize = (4,4))
labels = ["Delivery Time", "Sorting Time" ]
sns.distplot(df['Delivery Time'], kde = True)
sns.distplot(df['Sorting Time'],hist = True)
plt.legend(labels)

# %%
kurtosis_values = df.kurtosis()

categories = {}
for col, kurt in kurtosis_values.items():
    if kurt > 3:
        categories[col] = 'Leptokurtic'
    elif kurt < 3:
        categories[col] = 'Platykurtic'
    else:
        categories[col] = 'Mesokurtic'

# Displaying categories and kurtosis values
print("Column \t\t Category \t Kurtosis Value")
print("----------------------------------------------")
for col, category in categories.items():
    print(f"{col} \t {category} \t {kurtosis_values[col]}")
# Out:
# Column 		 Category 	 Kurtosis Value
# ----------------------------------------------
# Delivery Time 	 Platykurtic 	 0.31795982942685397
# Sorting Time 	 Platykurtic 	 -1.14845514534878

# %%
# Scatter plot
plt.figure(figsize=(12, 5))
plt.subplot(2, 2, 1)
sns.scatterplot(x='Delivery Time', y='Sorting Time', data=df)
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
# Line plot
plt.subplot(2, 2, 2)
sns.lineplot(x=df.index, y='Delivery Time', data=df, marker='o', label='Delivery Time')
sns.lineplot(x=df.index, y='Sorting Time', data=df, marker='o', label='Sorting Time')
plt.title('Line Plot')
plt.legend()

# %%
# Histogram
plt.subplot(2, 2, 3)
sns.histplot(df['Delivery Time'], bins=3, kde=True, color='skyblue', alpha=0.7)
plt.title('Histogram - Delivery Time')
# Out:
# Text(0.5, 1.0, 'Histogram - Delivery Time')

# %%
# Boxplot
plt.subplot(2, 2, 4)
sns.boxplot(data=df, orient='h')
plt.title('Boxplot')

plt.tight_layout()
plt.show()

# %% [markdown]
# # """"Flatter Distribution Shape: Both 'Delivery Time' and 'Sorting Time' display a platykurtic distribution
#     This suggests that the data tends to be more spread out with fewer extreme values or outliers."""
#
# """Outlier Interpretation: A platykurtic distribution often suggests a distribution where extreme values or
#     outliers are less frequent than in a normal distribution"""
#
# """In the case of 'Sorting Time,' this is further pronounced by the negative kurtosis,
# indicating fewer extreme values relative to a normal distribution.\n\nStatistical Analysis Consideration:
#             Understanding the kurtosis of a dataset is essential for interpreting the shape and characteristics
#             of the distribution."""
#
# """Statistical Analysis Consideration: Understanding the kurtosis of a dataset is essential for
#       interpreting the shape and characteristics of the distribution. In this scenario, the platykurtic nature
#                      indicates a wider spread of values around the mean, with less concentration towards the tails"""
